# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanish-2006/flyrank-ml-internship/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Tanish-2006/flyrank-ml-internship_week1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My Lane
#
# I chose **Structured Content Archetype Clustering** because websites contain many different types of pages, and treating every page the same can lead to poor SEO decisions. My goal is to group similar pages into meaningful content archetypes using their observable characteristics. These clusters can help identify which kinds of pages perform well, which are more likely to decline, and what type of action may be appropriate for each group. I chose this lane because it combines exploratory data analysis with machine learning and can provide useful insights for content strategy.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# **Decision:** Identify different content archetypes that can help prioritize SEO and content improvement efforts.
#
# **Unit of analysis:** One webpage.
#
# **Output:** A cluster label for each page along with a description of the cluster's characteristics.
#
# **Action:** SEO teams can review pages based on their cluster and decide whether to refresh, rewrite, merge, or maintain them.
#
# **Cost of a wrong call:** If pages are assigned to the wrong cluster, valuable pages may receive unnecessary updates while pages needing attention could be ignored, resulting in wasted effort and missed opportunities.
#
# **Why ML helps:** Simple rules cannot capture the complex relationships between multiple page features. Clustering algorithms can discover natural patterns in the data without requiring predefined labels.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total pages:", len(df))
print("Unique clients:", df["client_id"].nunique())
print("Average word count:", round(df["word_count"].mean(), 2))
print("Median CTR:", round(df["ctr"].median(), 4))
print("\nContent types:")
print(df["content_type"].value_counts().head())
# Out:
# Total pages: 30000
# Unique clients: 32
# Average word count: 3107.76
# Median CTR: 0.07
#
# Content types:
# content_type
# keyword article       27207
# feedly article         2096
# comparison article      697
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## What I can claim
#
# This project will identify patterns in structured content archetypes that may help group similar pages for analysis and optimization. The results can support content strategy and decision-making by showing how different page structures are associated with performance indicators.
#
# ## What I cannot claim
#
# This project cannot prove that a specific content structure causes better SEO performance or that Google ranks pages because of these patterns. The findings are observational and should be used as decision support rather than proof of causation.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
